# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
import warnings
# %matplotlib inline

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)

seed = 42
seed_everything(seed)
warnings.filterwarnings('ignore')
sns.set()

# %%
col_names = ["Age group", "Gender", "Category", "Marital status", 'Price', 'Brand name',
       'Aesthetics', 'Technological features', 'Functionality', 'Size',
       'Customisable options', 'Sustainability', "Likelihood", 'Wheels', 'Grilles', 'Headlights', 'Side mirrors', 'Bumpers',
       'Steering wheel', 'Centre compartment', 'Door handles', 'Dashboard', "Amount willing to spend", "Personalisation",
            "Amount willing to pay", "Experience"]
df = pd.read_excel("Product_Survey_Results_Modified.xlsx", index_col=0, parse_dates=True, header=None, names=col_names, skiprows=1)
df = df.reset_index(drop=True).dropna()
df.head()
# Out:
#   Age group  Gender                                           Category  \
# 0     20-30    Male  Do not own a car, but planning to purchase in ...
# 1     20-30    Male  Do not own a car, but planning to purchase in ...
# 2     20-30    Male  Do not own a car, but planning to purchase in ...
# 3     20-30  Female  Do not own a car, but planning to purchase in ...
# 4     20-30    Male  Do not own a car, but planning to purchase in ...
#
#   Marital status  Price  Brand name  Aesthetics  Technological features  \
# 0         Single      1           0           0                       0
# 1         Single      1           0           1                       1
# 2         Single      1           1           1                       0
# 3         Single      1           1           1                       1
# 4         Single      0           0           1                       0
#
#    Functionality  Size  ...  Side mirrors  Bumpers Steering wheel  \
# ...

# %%
# Preparing hash map for label encoding
age_map = {'20-30': 25,
           '31-40': 35,
           '41-50': 45,
           '51-60': 55}

df["Age group"] = df["Age group"].map(age_map) # replace age group with mean age per group

# %%
# Assuming each range of values in the age group follows a uniform distribution
df["Age"] = df["Age group"].copy()
df["Age"].values[df["Age"] == 25] = np.random.randint(20, 30, size=len(df["Age"].values[df["Age"] == 25]))
df["Age"].values[df["Age"] == 35] = np.random.randint(31, 40, size=len(df["Age"].values[df["Age"] == 35]))
df["Age"].values[df["Age"] == 45] = np.random.randint(41, 50, size=len(df["Age"].values[df["Age"] == 45]))
df["Age"].values[df["Age"] == 55] = np.random.randint(51, 60, size=len(df["Age"].values[df["Age"] == 55]))

# %%
# Assuming each range of values in the amount customers are willing to spend on car customisation follows a uniform distribution
df["Amount willing to spend"].values[df["Amount willing to spend"] == "100-500"] = np.random.randint(100, 500, size=len(df["Amount willing to spend"].values[df["Amount willing to spend"] == "100-500"]))
df["Amount willing to spend"].values[df["Amount willing to spend"] == "under 500"] = np.random.randint(0, 500, size=len(df["Amount willing to spend"].values[df["Amount willing to spend"] == "under 500"]))
df["Amount willing to spend"].values[df["Amount willing to spend"] == "500-1000"] = np.random.randint(500, 1000, size=len(df["Amount willing to spend"].values[df["Amount willing to spend"] == "500-1000"]))
df["Amount willing to spend"].values[df["Amount willing to spend"] == "over 1000"] = np.random.randint(1000, size=len(df["Amount willing to spend"].values[df["Amount willing to spend"] == "over 1000"]))

# %%
# Regardless, we retain the original categories through label encoding. We use the mean (where applicable) as the label.
# However, we group the categories "under 500" and "100-500" together.
df["Spending category"] = df["Amount willing to spend"].copy()
df["Spending category"].values[(df["Spending category"] > 0) & (df["Spending category"] <= 500)] = 250
df["Spending category"].values[(df["Spending category"] > 500) & (df["Spending category"] <= 1000)] = 750
df["Spending category"].values[df["Spending category"] > 1000] = 9999

# %%
# Assuming each range of values in the amount customers are willing to pay for personalisation follows a uniform distribution
df["Amount willing to pay"].values[df["Amount willing to pay"] == "100-500"] = np.random.randint(100, 500, size=len(df["Amount willing to pay"].values[df["Amount willing to pay"] == "100-500"]))
df["Amount willing to pay"].values[df["Amount willing to pay"] == "under 500"] = np.random.randint(0, 500, size=len(df["Amount willing to pay"].values[df["Amount willing to pay"] == "under 500"]))
df["Amount willing to pay"].values[df["Amount willing to pay"] == "500-1000"] = np.random.randint(500, 1000, size=len(df["Amount willing to pay"].values[df["Amount willing to pay"] == "500-1000"]))
df["Amount willing to pay"].values[df["Amount willing to pay"] == "over 1000"] = np.random.randint(1000, size=len(df["Amount willing to pay"].values[df["Amount willing to pay"] == "over 1000"]))

# %%
# Regardless, we retain the original categories through label encoding. We use the mean (where applicable) as the label.
# However, we group the categories "under 500" and "100-500" together.
df["Paying category"] = df["Amount willing to pay"].copy()
df["Paying category"].values[(df["Paying category"] > 0) & (df["Paying category"] <= 500)] = 250
df["Paying category"].values[(df["Paying category"] > 500) & (df["Paying category"] <= 1000)] = 750
df["Paying category"].values[df["Paying category"] > 1000] = 9999

# %%
df["Gender"].values[df["Gender"] == 0] = 1
df = df.drop(["Experience"], axis=1)
df.head()
# Out:
#    Age group  Gender                                           Category  \
# 0         25    Male  Do not own a car, but planning to purchase in ...
# 1         25    Male  Do not own a car, but planning to purchase in ...
# 2         25    Male  Do not own a car, but planning to purchase in ...
# 3         25  Female  Do not own a car, but planning to purchase in ...
# 4         25    Male  Do not own a car, but planning to purchase in ...
#
#   Marital status  Price  Brand name  Aesthetics  Technological features  \
# 0         Single      1           0           0                       0
# 1         Single      1           0           1                       1
# 2         Single      1           1           1                       0
# 3         Single      1           1           1                       1
# 4         Single      0           0           1                       0
#
#    Functionality  Size  ...  Steering wheel  Centre compartment Door handles  \
# ...

# %% [markdown]
# # 0a. Visualising Categorical Variables

# %%
cat_df = df.drop(['Amount willing to spend', 'Amount willing to pay', 'Age'], axis=1)
print(f"Number of columns is {len(cat_df.columns)}.")
# Out:
# Number of columns is 25.

# %%
# Plots the distribution of the variables in each category
plots_per_row = 5
f, axes = plt.subplots(5, plots_per_row, figsize=(15,30), sharey=True, sharex=True)
position = 0
for cat in cat_df:
    sns.countplot(x=cat, data=cat_df, ax=axes[position//plots_per_row, position%plots_per_row], palette="mako")
    position+=1

# %% [markdown]
# ### What factors are important to consumers when purchasing a car?

# %% [markdown]
# In general, we can see that price and functionality are the most important factors for consumers when purchasing a car. In contrast, consumers don't care much for customisable options or sustainability aspects of the car. Of all the features surveyed, the order of importance is as follows (in decreasing order): Price > Functionality > Technological features > Aesthetics > Brand name > Size > Sustainability > Customisable options.

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### 1a. Important factors to consider when purchasing a car based on age group

# %%
df_agegroup = df[['Price', 'Brand name', 'Aesthetics', 'Technological features', 'Functionality', 'Size', 'Customisable options', 'Sustainability', 'Age group']].groupby('Age group')


young_adults = df_agegroup.get_group(25).sum().to_dict()
young_adults.popitem()
young_adults = dict(sorted(young_adults.items(), key= lambda item: item[1], reverse=True))
young_adults_features = list(young_adults.keys())
young_adults_values = list(young_adults.values())
plt.figure(figsize=(20,10))
plt.bar(young_adults_features, young_adults_values, width=0.4, color='green')
plt.title('Important factors when deciding the purchase of Car for Age Group 21-30', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)
# Out:
# Text(0.5, 0, 'Factors')

# %%
mid_adults = df_agegroup.get_group(35).sum().to_dict()
mid_adults.popitem()
mid_adults = dict(sorted(mid_adults.items(), key= lambda item: item[1], reverse=True))
mid_adults_features = list(mid_adults.keys())
mid_adults_values = list(mid_adults.values())
plt.figure(figsize=(20,10))
plt.bar(mid_adults_features, mid_adults_values, width=0.4, color='orange')
plt.title('Important factors when deciding the purchase of Car for Age Group 31-40', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)
# Out:
# Text(0.5, 0, 'Factors')

# %%
adults = df_agegroup.get_group(45).sum().to_dict()
adults.popitem()
adults = dict(sorted(adults.items(), key= lambda item: item[1], reverse=True))
adults_features = list(adults.keys())
adults_values = list(adults.values())
plt.figure(figsize=(20,10))
plt.bar(mid_adults_features, mid_adults_values, width=0.4, color='blue')
plt.title('Important factors when deciding the purchase of Car for Age Group 41-50', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)
# Out:
# Text(0.5, 0, 'Factors')

# %%
old_adults = df_agegroup.get_group(55).sum().to_dict()
old_adults.popitem()
old_adults = dict(sorted(old_adults.items(), key= lambda item: item[1], reverse=True))
old_adults_features = list(old_adults.keys())
old_adults_values = list(old_adults.values())
plt.figure(figsize=(20,10))
plt.bar(old_adults_features, old_adults_values, width=0.4, color='red')
plt.title('Important factors when deciding the purchase of Car for Age Group 51-60', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)
# Out:
# Text(0.5, 0, 'Factors')

# %% [markdown]
# Based on the 4 different graphs above, we can see that Price are the most important factor for all age groups. For age group 51-60, their next priority is brand name while the other age groups prioritise functionality. People from 51-60 age group are also not interested in customisable options.

# %% [markdown]
# ## 1b. Important factors to consider when purchasing a car based on Gender

# %%
df_gender = df[['Price', 'Brand name', 'Aesthetics', 'Technological features', 'Functionality', 'Size', 'Customisable options', 'Sustainability', 'Gender']].groupby('Gender')


male = df_gender.get_group("Male").sum().to_dict()
male.popitem()
male = dict(sorted(male.items(), key= lambda item: item[1], reverse=True))
male_features = list(male.keys())
male_values = list(male.values())
plt.figure(figsize=(20,10))
plt.bar(male_features, male_values, width=0.4, color='green')
plt.title('Important factors when deciding the purchase of Car for Males', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)

female = df_gender.get_group("Female").sum().to_dict()
female.popitem()
female = dict(sorted(female.items(), key= lambda item: item[1], reverse=True))
female_features = list(female.keys())
female_values = list(female.values())
plt.figure(figsize=(20,10))
plt.bar(female_features, female_values, width=0.4, color='green')
plt.title('Important factors when deciding the purchase of Car for Females', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)
# Out:
# Text(0.5, 0, 'Factors')

# %% [markdown]
# ## 1c. Important factors to consider when purchasing a car based on Relationship Status

# %%
df_marital = df[['Price', 'Brand name', 'Aesthetics', 'Technological features', 'Functionality', 'Size', 'Customisable options', 'Sustainability', 'Marital status']].groupby('Marital status')


married_child = df_marital.get_group("Married with children").sum().to_dict()
married_child.popitem()
married_child = dict(sorted(married_child.items(), key= lambda item: item[1], reverse=True))
married_child_features = list(married_child.keys())
married_child_values = list(married_child.values())
plt.figure(figsize=(20,10))
plt.bar(married_child_features, married_child_values, width=0.4, color='green')
plt.title('Important factors when deciding the purchase of Car for Married Couples', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)
# Out:
# Text(0.5, 0, 'Factors')

# %%
married = df_marital.get_group("Married with no children").sum().to_dict()
married.popitem()
married = dict(sorted(married_child.items(), key= lambda item: item[1], reverse=True))
married_features = list(married_child.keys())
married_values = list(married_child.values())
plt.figure(figsize=(20,10))
plt.bar(married_features, married_values, width=0.4, color='green')
plt.title('Important factors when deciding the purchase of Car for Married Couples with no Children', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)
# Out:
# Text(0.5, 0, 'Factors')

# %%
single = df_marital.get_group("Single").sum().to_dict()
single.popitem()
single = dict(sorted(single.items(), key= lambda item: item[1], reverse=True))
single_features = list(single.keys())
single_values = list(single.values())
plt.figure(figsize=(20,10))
plt.bar(single_features, single_values, width=0.4, color='green')
plt.title('Important factors when deciding the purchase of Car for Married Couples with no Children', size=18, weight='bold')
plt.ylabel('Number of Consumers', size=14)
plt.xlabel('Factors', size=14)
# Out:
# Text(0.5, 0, 'Factors')

# %% [markdown]
# ### 2a and 3a. What percentage of consumers are interested in customisation (without additional surcharge) and personalised design?

# %%
def without_hue(ax, feature):
    total = len(feature)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), size = 12)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12, 8), sharey=True)
ax1 = sns.countplot(df["Likelihood"], ax=axes[0], palette="crest");
ax2 = sns.countplot(df["Personalisation"], ax=axes[1], palette="Reds");

ax1.set(xlabel="Likelihood of opting for customised vehicle if no additional surcharge", ylabel="Number of customers");
ax2.set(xlabel="Interested in designing own components to personalise car", ylabel="Number of customers");

without_hue(ax1, df["Likelihood"])
without_hue(ax2, df["Personalisation"])

# %% [markdown]
# We can see that the vast majority of customers are inclined to customise their vehicle if there weren't any extra charges (72.7% are very likely, 25.3% are likely = 98% of customers are inclined). Additionally, a large majority of consumers are also interested in designing their own components to personalise their car (55.6% + 31.3% = 86.9%). However, most of them only want to do it with professional help (55.6% of overall respondents, 64% of respondents who were interested).

# %% [markdown]
# ### 2b and 3b. How much are consumers willing to pay for customisation & personalised design?

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(15, 8))
labels = ["500-1000", "Under 500", "Not willing to pay"]
df["Spending category"].value_counts().plot.pie(ax = axes[0], autopct='%1.1f%%', shadow=True, labels=labels, title="Amount customers are willing to spend for customisation");
df["Paying category"].value_counts().plot.pie(ax = axes[1], autopct='%1.1f%%', shadow=True, labels=labels, title="Amount customers are willing to pay for personalised design");

# %% [markdown]
# Vast majority of respondents are willing to pay for customisation (86.9%) and personalised design (88.9%). They roughly follow the same distribution with regards to the range of amount customers are willing to pay. However, it remains to be seen if people who are willing to spend on customisation are also the people who are willing to pay for personalised design.
#
# Among the people who are willing to pay for customisation, 47.6% of them are willing to pay under 500 dollars and 52.4% of them are willing to pay between 500 to 1000 dollars. Among the people who are willing to pay for personalisation, 44.3% of them are willing to pay under 500 dollars and 55.7% are willing to pay between 500 to 1000 dollars.

# %%
# Calculating the average amount customers are willing to spend for customisation and personalised design
custom_mean = sum(df["Spending category"])/len(df["Spending category"])
personal_mean = sum(df["Paying category"])/len(df["Paying category"])

# Exclude people who are not willing to pay for customisation or personalised design
custom_mean_ex = sum(df["Spending category"].values[df["Spending category"] != 0])/len(df["Spending category"].values[df["Spending category"] != 0])
personal_mean_ex = sum(df["Paying category"].values[df["Paying category"] != 0])/len(df["Paying category"].values[df["Paying category"] != 0])

print(f"Average amount customers are willing to spend on customisation: ${custom_mean:.2f}.")
print(f"Average amount customers are willing to pay on personalised design: ${personal_mean:.2f}.")
print(f"Average amount customers are willing to spend on customisation (excluding those who are not willing to spend): ${custom_mean_ex:.2f}.")
print(f"Average amount customers are willing to pay on personalised design (excluding those who are not willing to pay): ${personal_mean_ex:.2f}.")
# Out:
# Average amount customers are willing to spend on customisation: $444.44.
# Average amount customers are willing to pay on personalised design: $469.70.
# Average amount customers are willing to spend on customisation (excluding those who are not willing to spend): $511.63.
# Average amount customers are willing to pay on personalised design (excluding those who are not willing to pay): $528.41.

# %%
# Label encoding categorical variables with their hash maps
gender_map = {"Male": 1,
             "Female": 2,
             "Prefer not to say": 0}
category_map = {'Do not own a car, but planning to purchase in future': 0,
               'Own a car': 1,
               'Own more than one car': 2}
status_map = {"Single": 0,
             "Married with no children": 1,
             "Married with children": 2}
likelihood_map = {"Not likely": 0,
                 "Likely": 1,
                 "Very likely": 2}
personalise_map = {"No": 0,
                  "Only with professional help": 1,
                  "Yes": 2}

df["Gender"] = df["Gender"].map(gender_map)
df["Category"] = df["Category"].map(category_map)
df["Marital status"] = df["Marital status"].map(status_map)
df["Likelihood"] = df["Likelihood"].map(likelihood_map)
df["Personalisation"] = df["Personalisation"].map(personalise_map)

# %% [markdown]
# ###  2c. and 3c. Among respondents who indicated interest in customisation, is there a relationship between their degree of interest and the amount they are willing to spend on customisation? Can we answer the same question for respondents who indicated interest in personalisation?

# %%
df["Spending category"] = df["Spending category"].astype("int")
df["Paying category"] = df["Paying category"].astype("int")

# %% [markdown]
# Traditionally, to measure the association between two nominal (categorical) variables, we use the Cramer's V statistic. The Cramer's V statistic outputs a value between 0 and 1, where a higher value indicates a higher association.

# %%
import scipy.stats as ss

def cramers_corrected_stat(x,y):
    """ calculate Cramers V statistic for categorial-categorial association.
     uses correction from Bergsma and Wicher, 
     Journal of the Korean Statistical Society 42 (2013): 323-328
    """
    result=-1
    if len(x.value_counts())==1 :
        print("First variable is constant")
    elif len(y.value_counts())==1:
        print("Second variable is constant")
    else:   
        conf_matrix=pd.crosstab(x, y)

    if conf_matrix.shape[0]==2:
        correct=False
    else:
        correct=True

    chi2 = ss.chi2_contingency(conf_matrix, correction=correct)[0]

    n = sum(conf_matrix.sum())
    phi2 = chi2/n
    r,k = conf_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    result=np.sqrt(phi2corr / min( (kcorr-1), (rcorr-1)))
    return round(result,6)

# %%
cvs_customise = cramers_corrected_stat(df["Likelihood"], df["Spending category"])
cvs_personalise = cramers_corrected_stat(df["Personalisation"], df["Paying category"])

print(f"Measure of association between likelihood of customisation and amount willing to spend on customisation is {cvs_customise:.2f}.")
print(f"Measure of association between interest in personalised design and amount willing to pay for personalisation is {cvs_personalise:.2f}.")
# Out:
# Measure of association between likelihood of customisation and amount willing to spend on customisation is 0.00.
# Measure of association between interest in personalised design and amount willing to pay for personalisation is 0.07.

# %% [markdown]
# From this, we can see that the measure of association for both cases are very low (in fact, no association between likelihood of customisation and amount willing to spend on customisation).
#
# Additionally, we make a reasonable assumption that the higher the value of our label, the higher the degree of interest. i.e. We labelled "Likely to customise" as 1, and "Very likely to customise" as 2.
#
# For degree of interest expressed in designing own components to personalise their cars, we assume that people who only want to do it with professional help have a lower degree of interest than people who readily agree with or without professional help.
#
# With this assumption, we can also apply Pearson's correlation between the variables to see if there is a linear relationship between them.

# %% [markdown]
# ### Is there a correlation between people who are willing to spend on customisation and people who are willing to pay for personalisation?

# %%
custom_corr = df[["Likelihood", "Spending category"]].corr()
personal_corr = df[["Personalisation", "Paying category"]].corr()
total_corr = df[["Likelihood", "Spending category", "Personalisation", "Paying category"]].corr()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(15, 5));
sns.heatmap(custom_corr, annot=True, fmt=".5f", cmap="YlGnBu", ax=axes[0]);
sns.heatmap(personal_corr, annot=True, fmt=".5f", cmap="YlOrRd", ax=axes[1]);

# %%
plt.figure(figsize=(12,8))
sns.heatmap(total_corr, annot=True, fmt=".5f");

# %% [markdown]
# From the first two heatmaps, we can see that the Pearson's correlation follows the same trend as the Cramer's V statistic. There is a negligible positive correlation between likelihood of customisation and amount willing to spend on customisation and a low positive correlation between interest in personalised design and amount willing to pay for personalisation.
#
# However, there is a strong correlation between amount willing to spend on customisation and amount willing to pay for personalisation. This means that people who were willing to spend more on customisation were also willing to pay more for personalisation.

# %% [markdown]
# ### 2d. What components are usually customised among customers willing to pay?

# %%
all_parts = df[['Wheels', 'Grilles', 'Headlights', 'Side mirrors', 'Bumpers',
                'Steering wheel', 'Centre compartment', 'Door handles', 'Dashboard', 
                'Likelihood', 'Spending category']]
ext_parts = df[['Wheels', 'Grilles', 'Headlights', 'Side mirrors', 'Bumpers', 'Likelihood', 'Spending category']]
int_parts = df[['Steering wheel', 'Centre compartment', 'Door handles', 'Dashboard', 'Likelihood', 'Spending category']]

all_parts = all_parts[(df["Likelihood"] > 0) & (df["Spending category"] > 0)]
ext_parts = ext_parts[(df["Likelihood"] > 0) & (df["Spending category"] > 0)]
int_parts = int_parts[(df["Likelihood"] > 0) & (df["Spending category"] > 0)]

# %%
# Plots the distribution of the variables in each category
plots_per_row = 5
f, axes = plt.subplots(2, plots_per_row, figsize=(12,10), sharey=True)
position = 0
for part in all_parts.drop(["Likelihood", "Spending category"], axis=1):
    sns.countplot(x=part, data=all_parts, ax=axes[position//plots_per_row, position%plots_per_row])
    position+=1

# %%
exterior_components = ext_parts.drop(["Spending category", "Likelihood"], axis=1).sum().sort_values(ascending=False).to_dict()
exterior_types = exterior_components.keys()
exterior_count = exterior_components.values()

interior_components = int_parts.drop(["Spending category", "Likelihood"], axis=1).sum().sort_values(ascending=False).to_dict()
interior_types = interior_components.keys()
interior_count = interior_components.values()

fig, ax = plt.subplots(1, 2, figsize=(25, 10))

plt.subplot(1, 2, 1)
plt.bar(exterior_types, exterior_count)
plt.title('Most popular Exterior components')

plt.subplot(1, 2, 2)
plt.bar(interior_types, interior_count)
plt.title('Most popular Interior components')
# Out:
# Text(0.5, 1.0, 'Most popular Interior components')

# %% [markdown]
# In general, popular components are (in decreasing order of popularity):
# - Wheels
# - Steering wheels
# - Dashboards
# - Centre compartments
#
# Unpopular components are (in decreasing order of unpopularity):
# - Side mirrors
# - Door handles
# - Bumpers
# - Grilles
# - Headlights

# %% [markdown]
# ### 3e. Among respondents into personalised design, which parts do they want to customise?

# %%
personal_parts = df[['Wheels', 'Grilles', 'Headlights', 'Side mirrors', 'Bumpers',
                'Steering wheel', 'Centre compartment', 'Door handles', 'Dashboard', 
                "Personalisation"]]
personal_parts = personal_parts[personal_parts["Personalisation"] > 0]

# %%
plots_per_row = 5
f, axes = plt.subplots(2, plots_per_row, figsize=(12,10), sharey=True)
position = 0
for part in personal_parts:
    sns.countplot(x=part, data=personal_parts, ax=axes[position//plots_per_row, position%plots_per_row], palette="twilight_shifted")
    position+=1

# %% [markdown]
# For respondents into personalised design, popular components are (in decreasing order of popularity):
# - Dashboards
# - Wheels
# - Steering wheels
# - Centre compartments
#
# Unpopular components are (in decreasing order of unpopularity):
# - Side mirrors
# - Door handles
# - Grilles
# - Bumpers
# - Headlights

# %% [markdown]
# ### Which vehicle parts are usually customized based on the spending power of the customer?

# %%
# Plots the distribution of the variables according to people who were likely to customise vs people who were very likely to customise
plots_per_row = 5
f, axes = plt.subplots(2, plots_per_row, figsize=(15,10), sharey=True)
position = 0
for part in all_parts.drop("Likelihood", axis=1):
    sns.countplot(x=part, data=all_parts, hue=all_parts["Spending category"], ax=axes[position//plots_per_row, position%plots_per_row], palette="twilight")
    position+=1

# %% [markdown]
# Among people who are willing to shell out between 500-1000 dollars:
# - Wheels, steering wheels and dashboards are popular (in decreasing order of popularity)
# - Side mirrors, door handles, grilles and bumpers are unpopular (in decreasing order of unpopularity)
# - The rest have mixed reception
#
# Among people who are willing to shell out between 0-500 dollars:
# - Dashboards, wheels, steering wheels are popular (in decreasing order of popularity)
# - Door handles, side mirrors, bumpers, and grilles are unpopular (in decreasing order of unpopularity)
# - The rest have mixed reception

# %% [markdown]
# # Predictive modelling
# Can we find out how much a customer is willing to pay from features such as age group, gender, marital status and car ownership? In the following exercise, we aim to predict how much a customer is willing to spend on customisation and personalised design. We will be using the random forest algorithm here as it is a robust, high-performing predictive algorithm for categorical variables.

# %%
new_df = df[['Age group', 'Gender', 'Category', 'Marital status',
                'Spending category', 'Paying category']]

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
clf = DecisionTreeClassifier()
rf = RandomForestClassifier()
rf_prime = RandomForestClassifier()

X = new_df.iloc[:, :-2]
y = new_df.iloc[:, -1]
y_prime = new_df.iloc[:, -2]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
X_trainp, X_testp, y_trainp, y_testp = train_test_split(X, y_prime, stratify=y_prime, random_state=42)

rf.fit(X_train, y_train)
rf_prime.fit(X_trainp, y_trainp);

# %%
from sklearn.metrics import classification_report
y_pred = rf.predict(X_test)
y_predp = rf_prime.predict(X_testp)

# %%
print("Classification report for predicting how much a customer will pay for personalised design")
print(classification_report(y_test, y_pred))
# Out:
# Classification report for predicting how much a customer will pay for personalised design
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#          250       0.75      0.60      0.67        10
#          750       0.65      0.92      0.76        12
#
#     accuracy                           0.68        25
#    macro avg       0.47      0.51      0.48        25
# weighted avg       0.61      0.68      0.63        25

# %%
print("Classification report for predicting how much a customer will spend on customisation")
print(classification_report(y_testp, y_predp))
# Out:
# Classification report for predicting how much a customer will spend on customisation
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#          250       0.62      0.50      0.56        10
#          750       0.59      0.83      0.69        12
#
#     accuracy                           0.60        25
#    macro avg       0.40      0.44      0.42        25
# weighted avg       0.53      0.60      0.55        25

# %% [markdown]
# We can see that on average, our algorithm is right 64% of the time.

# %%
importances = rf.feature_importances_
feature_names = ['Age group', 'Gender', 'Car ownership', 'Marital status']
rf_importances = pd.Series(importances, index=feature_names)

importances_p = rf_prime.feature_importances_
rfp_importances = pd.Series(importances_p, index=feature_names)

fig, axes = plt.subplots(nrows=1, ncols=2);
ax = rf_importances.plot.barh(figsize=(12,5), ax=axes[0])
ax.set_title("Feature importances using MDI")
ax.set_xlabel("Willingness to pay for personalised design")

ax1 = rfp_importances.plot.barh(figsize=(12,5), ax=axes[1], cmap="Oranges_r")
ax1.set_title("Feature importances using MDI")
ax1.set_xlabel("Willingness to spend on customisation")
fig.tight_layout();

# %% [markdown]
# We can see that for both categories, gender is the most important factor for the random forest algorithm. Let's build a decision tree to visualise how gender performs alone as a predictive variable.

# %%
X = new_df.iloc[:, 1:2]
clf.fit(X, y);

# %%
# Predicting how much a customer is willing to pay for personalised design
plt.figure(figsize=(10, 10))
plot_tree(clf, feature_names = ["Gender"], 
          class_names = ["500-1000", "below 500", "0"], filled=True, rounded=True);

# %%
# Predicting how much a customer is willing to spend on customisation
clf.fit(X, y_prime);
ax = plt.figure(figsize=(10, 10))
plot_tree(clf, feature_names = ["Gender"], 
          class_names = ["500-1000", "below 500", "0"], filled=True, rounded=True);

# %% [markdown]
# # Association Rule Learning
# Customers who chose to customise wheels (or any other part) also chose to customise what other components?

# %%
df = pd.read_excel("Product_Survey_Results.xlsx")
df.head()
# Out:
#                      Timestamp Which age group do you belong to?  \
# 0  2021/09/26 4:11:56 PM GMT+8                             20-30
# 1  2021/10/08 1:03:51 PM GMT+8                             20-30
# 2  2021/10/08 1:11:45 PM GMT+8                             20-30
# 3  2021/10/08 1:16:36 PM GMT+8                             20-30
# 4  2021/10/08 1:22:02 PM GMT+8                             20-30
#
#   What is your gender?         Which category do you currently belong to?  \
# 0                 Male  Do not own a car, but planning to purchase in ...
# 1                 Male  Do not own a car, but planning to purchase in ...
# 2                 Male  Do not own a car, but planning to purchase in ...
# 3               Female  Do not own a car, but planning to purchase in ...
# 4                 Male  Do not own a car, but planning to purchase in ...
#
#   Which of the following best describes you?  \
# 0                                     Single
# ...

# %%
asl = df[['Which of the following exterior components would you choose to customise (texture, layout, size, etc)? ',
   'Which of the following interior components would you choose to customise (texture, layout, size, etc)? ']]
asl = asl.rename(columns={'Which of the following exterior components would you choose to customise (texture, layout, size, etc)? ': "Exterior components",
                   'Which of the following interior components would you choose to customise (texture, layout, size, etc)? ': "Interior components"})
asl.head()
# Out:
#                       Exterior components  \
# 0                                 Grilles
# 1         Headlights;Side mirrors;Bumpers
# 2                                  Wheels
# 3  Wheels;Grilles;Headlights;Side mirrors
# 4  Wheels;Grilles;Headlights;Side mirrors
#
#                                  Interior components
# 0                                 Centre compartment
# 1          Centre compartment;Door handles;Dashboard
# 2  Steering wheel;Centre compartment;Door handles...
# 3                                 Centre compartment
# 4                           Steering wheel;Dashboard

# %%
asl_ext = asl["Exterior components"].str.split(";", expand=True)
asl_int = asl["Interior components"].str.split(";", expand=True)
asl = asl_ext.merge(asl_int, left_index=True, right_index=True)
asl.head()
# Out:
#           0_x           1_x         2_x           3_x   4_x  \
# 0     Grilles          None        None          None  None
# 1  Headlights  Side mirrors     Bumpers          None  None
# 2      Wheels          None        None          None  None
# 3      Wheels       Grilles  Headlights  Side mirrors  None
# 4      Wheels       Grilles  Headlights  Side mirrors  None
#
#                   0_y                 1_y           2_y        3_y   4_y
# 0  Centre compartment                None          None       None  None
# 1  Centre compartment        Door handles     Dashboard       None  None
# 2      Steering wheel  Centre compartment  Door handles  Dashboard  None
# 3  Centre compartment                None          None       None  None
# 4      Steering wheel           Dashboard          None       None  None

# %%
def squeeze_nan(x):
    original_columns = x.index.tolist()

    squeezed = x.dropna()
    squeezed.index = [original_columns[n] for n in range(squeezed.count())]

    return squeezed.reindex(original_columns, fill_value=np.nan)
asl = asl.apply(squeeze_nan, axis=1)

# %%
components = []
for i in range(0, len(asl)):
    components.append([str(asl.values[i,j]) for j in range(0, len(asl.columns))])

# %%
# min_support = minimum number rows containing x (any component) / total number of rows
# min_confidence = minimum number rows containing x (any component) and y (complementary component) / total number of rows
# min_lift = min_confidence / min_support
# min_length = minimum number of components in each associated rule
from apyori import apriori
rules = apriori(components, min_support=0.05, min_confidence=0.8, min_lift=3, min_length=2)

# %% [markdown]
# We will be using the Apriori algorithm for association rule learning between components to find out what other parts do customers, who want to customise "x" component, also want to customise?
#
# From this, we are saying we want to find associated rules between any 2 or more components that are present in at least 5 of the 100 rows (of feedback) with a confidence of 80% (the rule holds true at least 80% of the time).

# %%
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'Centre compartment', 'Door handles', 'Bumpers', 'Grilles', 'Side mirrors'}), support=0.06, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Side mirrors', 'Door handles', 'Grilles'}), items_add=frozenset({'Centre compartment', 'Bumpers'}), confidence=0.857142857142857, lift=3.296703296703296)]),
#  RelationRecord(items=frozenset({'Door handles', 'Bumpers', 'Steering wheel', 'Headlights', 'Grilles'}), support=0.07, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Headlights', 'Door handles', 'Grilles'}), items_add=frozenset({'Steering wheel', 'Bumpers'}), confidence=0.8750000000000001, lift=3.240740740740741)]),
#  RelationRecord(items=frozenset({'Door handles', 'Bumpers', 'Steering wheel', 'Grilles', 'Side mirrors'}), support=0.07, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Side mirrors', 'Door handles', 'Grilles'}), items_add=frozenset({'Steering wheel', 'Bumpers'}), confidence=1.0, lift=3.7037037037037033)]),
# ...

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

results_df = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
results_df = results_df.replace('nan', np.nan).dropna()
results_df.sort_values('Support', ascending=False).drop_duplicates(subset=['Left Hand Side', 'Right Hand Side'])
# Out:
#    Left Hand Side     Right Hand Side  Support  Confidence      Lift
# 2    Side mirrors      Steering wheel     0.07    1.000000  3.703704
# 4    Side mirrors        Door handles     0.07    0.875000  3.125000
# 1      Headlights      Steering wheel     0.07    0.875000  3.240741
# 0    Side mirrors  Centre compartment     0.06    0.857143  3.296703
# 14         Wheels      Steering wheel     0.06    0.857143  3.174603
# 10     Headlights              Wheels     0.05    0.833333  3.623188

# %% [markdown]
# According to the top 3 rules, we can see that
# - Customers who want to customise side mirrors also want to customise steering wheels 100% of the time, and this rule appears in 7 feedbacks.
# - Customers who want to customise side mirrors also want to customise door handles 87.5% of the time, and this rule appears in 7 feedbacks.
# - Customers who want to customise headlights also want to customise steering wheels 87.5% of the time, and this rule appears in 7 feedbacks.
